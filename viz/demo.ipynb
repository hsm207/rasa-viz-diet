# %% [markdown]
# # Libraries

# %%
import utils
import numpy as np
# Out:
# 2022-05-24 23:17:06.968603: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-24 23:17:06.968822: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Setup

# %%
# %ls -l ../bots/moodbot/models/basic
# Out:
# total 74280
# -rw-r--r-- 1 root root 24967610 May 24 20:11 20220524-201138.tar.gz
# -rw-r--r-- 1 root root 24946669 May 24 20:34 20220524-203404.tar.gz
# -rw-r--r-- 1 root root 24964571 May 24 20:52 20220524-205250.tar.gz

# %%
BOT_DIR = "../bots/moodbot"
MODEL_DIR = f"{BOT_DIR}/models/basic"
MODEL_NAME = "20220524-201138"

DATA_DIR = "../bots/moodbot/data"
DOMAIN_PATH = "../bots/moodbot/domain.yml"

# %% [markdown]
# # Extracting the `_CLS_` token features

# %% [markdown]
# Example usage given a specific utterance:

# %%
interpreter = utils.create_interpreter(MODEL_DIR, MODEL_NAME)
# Out:
# 2022-05-24 23:17:25.239544: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-05-24 23:17:25.239688: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-24 23:17:25.239749: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (78d60810b291): /proc/driver/nvidia/version does not exist
# 2022-05-24 23:17:25.240456: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
utterance = "hello world"
cls_token_features = utils.extract_cls_features(utterance, interpreter)
cls_token_features.shape
# Out:
# (256,)

# %% [markdown]
# Example usage given a data folder:

# %%
df = await utils.get_nlu_data(DATA_DIR, DOMAIN_PATH, interpreter)
df.head(5)
# Out:
#            text intent                                           features
# 0           hey  greet  [-0.16692917, 0.45729128, -0.15825692, -0.1699...
# 1         hello  greet  [-0.14315224, 1.8836175, -0.16950037, -0.16570...
# 2            hi  greet  [-0.16990316, 0.52838147, -0.13793921, -0.1316...
# 3   hello there  greet  [-0.16780633, 1.247242, -0.16191453, -0.159371...
# 4  good morning  greet  [-0.15276307, 0.47844854, -0.027816072, -0.161...

# %%
df = utils.add_reduced_dimension(df)
df.head(5)
# Out:
#            text intent                                           features  \
# 0           hey  greet  [-0.16692917, 0.45729128, -0.15825692, -0.1699...
# 1         hello  greet  [-0.14315224, 1.8836175, -0.16950037, -0.16570...
# 2            hi  greet  [-0.16990316, 0.52838147, -0.13793921, -0.1316...
# 3   hello there  greet  [-0.16780633, 1.247242, -0.16191453, -0.159371...
# 4  good morning  greet  [-0.15276307, 0.47844854, -0.027816072, -0.161...
#
#          x1        x2
# 0 -3.187491 -6.625868
# 1 -3.310973 -6.457674
# 2 -3.321210 -6.638309
# 3 -3.287459 -6.407251
# 4 -3.147148 -5.714293

# %% [markdown]
# # Visualize Features in 2D

# %%
utils.visualize_features(df)
# Out:
# alt.Chart(...)
